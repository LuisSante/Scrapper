# %%
output = "2023-12-05 15:34:00 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrapper_database)\n2023-12-05 15:34:00 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.12, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.10.9 (tags/v3.10.9:1dd9be6, Dec  6 2022, 20:01:21) [MSC v.1934 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Windows-10-10.0.22000-SP0\n2023-12-05 15:34:00 [scrapy.addons] INFO: Enabled addons:\n[]\n2023-12-05 15:34:00 [asyncio] DEBUG: Using selector: SelectSelector\n2023-12-05 15:34:00 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor\n2023-12-05 15:34:00 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.windows_events._WindowsSelectorEventLoop\n2023-12-05 15:34:00 [scrapy.extensions.telnet] INFO: Telnet Password: 8c8894cf6cbad990\n2023-12-05 15:34:00 [scrapy.middleware] INFO: Enabled extensions:\n['scrapy.extensions.corestats.CoreStats',\n 'scrapy.extensions.telnet.TelnetConsole',\n 'scrapy.extensions.logstats.LogStats']\n2023-12-05 15:34:00 [scrapy.crawler] INFO: Overridden settings:\n{'BOT_NAME': 'scrapper_database',\n 'FEED_EXPORT_ENCODING': 'utf-8',\n 'NEWSPIDER_MODULE': 'scrapper_database.spiders',\n 'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',\n 'ROBOTSTXT_OBEY': True,\n 'SPIDER_MODULES': ['scrapper_database.spiders'],\n 'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}\n2023-12-05 15:34:00 [scrapy.middleware] INFO: Enabled downloader middlewares:\n['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',\n 'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',\n 'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',\n 'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',\n 'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',\n 'scrapy.downloadermiddlewares.retry.RetryMiddleware',\n 'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',\n 'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',\n 'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',\n 'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',\n 'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',\n 'scrapy.downloadermiddlewares.stats.DownloaderStats']\n2023-12-05 15:34:00 [scrapy.middleware] INFO: Enabled spider middlewares:\n['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',\n 'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',\n 'scrapy.spidermiddlewares.referer.RefererMiddleware',\n 'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',\n 'scrapy.spidermiddlewares.depth.DepthMiddleware']\n2023-12-05 15:34:00 [scrapy.middleware] INFO: Enabled item pipelines:\n[]\n2023-12-05 15:34:00 [scrapy.core.engine] INFO: Spider opened\n2023-12-05 15:34:00 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)\n2023-12-05 15:34:00 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023\n2023-12-05 15:34:01 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://quotes.toscrape.com/robots.txt> (referer: None)\n2023-12-05 15:34:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://quotes.toscrape.com/tag/humor/> (referer: None)\n2023-12-05 15:34:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://quotes.toscrape.com/tag/humor/>\n\n{'author': 'Jane Austen', 'text': '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”'}\n2023-12-05 15:34:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://quotes.toscrape.com/tag/humor/>\n\n{'author': 'Steve Martin', 'text': '“A day without sunshine is like, you know, night.”'}\n2023-12-05 15:34:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://quotes.toscrape.com/tag/humor/>\n\n{'author': 'Garrison Keillor', 'text': '“Anyone who thinks sitting in church can make you a Christian must also think that sitting in a garage can make you a car.”'}\n2023-12-05 15:34:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://quotes.toscrape.com/tag/humor/>\n\n{'author': 'Jim Henson', 'text': '“Beauty is in the eye of the beholder and it may be necessary from time to time to give a stupid or misinformed beholder a black eye.”'}\n2023-12-05 15:34:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://quotes.toscrape.com/tag/humor/>\n\n{'author': 'Charles M. Schulz', 'text': \"“All you need is love. But a little chocolate now and then doesn't hurt.”\"}\n2023-12-05 15:34:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://quotes.toscrape.com/tag/humor/>\n\n{'author': 'Suzanne Collins', 'text': \"“Remember, we're madly in love, so it's all right to kiss me anytime you feel like it.”\"}\n2023-12-05 15:34:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://quotes.toscrape.com/tag/humor/>\n\n{'author': 'Charles Bukowski', 'text': '“Some people never go crazy. What truly horrible lives they must lead.”'}\n2023-12-05 15:34:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://quotes.toscrape.com/tag/humor/>\n\n{'author': 'Terry Pratchett', 'text': '“The trouble with having an open mind, of course, is that people will insist on coming along and trying to put things in it.”'}\n2023-12-05 15:34:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://quotes.toscrape.com/tag/humor/>\n\n{'author': 'Dr. Seuss', 'text': '“Think left and think right and think low and think high. Oh, the thinks you can think up if only you try!”'}\n2023-12-05 15:34:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://quotes.toscrape.com/tag/humor/>\n\n{'author': 'George Carlin', 'text': '“The reason I talk to myself is because I’m the only one whose answers I accept.”'}\n2023-12-05 15:34:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://quotes.toscrape.com/tag/humor/page/2/> (referer: https://quotes.toscrape.com/tag/humor/)\n2023-12-05 15:34:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://quotes.toscrape.com/tag/humor/page/2/>\n\n{'author': 'W.C. Fields', 'text': '“I am free of all prejudice. I hate everyone equally. ”'}\n2023-12-05 15:34:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://quotes.toscrape.com/tag/humor/page/2/>\n\n{'author': 'Jane Austen', 'text': \"“A lady's imagination is very rapid; it jumps from admiration to love, from love to matrimony in a moment.”\"}\n2023-12-05 15:34:02 [scrapy.core.engine] INFO: Closing spider (finished)\n2023-12-05 15:34:02 [scrapy.statscollectors] INFO: Dumping Scrapy stats:\n{'downloader/request_bytes': 746,\n 'downloader/request_count': 3,\n 'downloader/request_method_count/GET': 3,\n 'downloader/response_bytes': 16064,\n 'downloader/response_count': 3,\n 'downloader/response_status_count/200': 2,\n 'downloader/response_status_count/404': 1,\n 'elapsed_time_seconds': 1.45505,\n 'finish_reason': 'finished',\n 'finish_time': datetime.datetime(2023, 12, 5, 20, 34, 2, 93304, tzinfo=datetime.timezone.utc),\n 'item_scraped_count': 12,\n 'log_count/DEBUG': 18,\n 'log_count/INFO': 10,\n 'request_depth_max': 1,\n 'response_received_count': 3,\n 'robotstxt/request_count': 1,\n 'robotstxt/response_count': 1,\n 'robotstxt/response_status_count/404': 1,\n 'scheduler/dequeued': 2,\n 'scheduler/dequeued/memory': 2,\n 'scheduler/enqueued': 2,\n 'scheduler/enqueued/memory': 2,\n 'start_time': datetime.datetime(2023, 12, 5, 20, 34, 0, 638254, tzinfo=datetime.timezone.utc)}\n2023-12-05 15:34:02 [scrapy.core.engine] INFO: Spider closed (finished)\n"

import ast
import re
import pandas as pd

pattern = re.compile(r'{[^}]*}')
matches = pattern.findall(output)
matches = [match.replace("“", "") for match in matches]
matches = [match.replace("”", "") for match in matches]
matches = [match.replace("\"", "\'") for match in matches]
matches = [match.replace("’", "'") for match in matches]
matches = [match.replace("'m", " am") for match in matches]
matches = [match.replace("'re", " are") for match in matches]
matches = [match.replace("'s", " is") for match in matches]
matches = [match.replace("'ve", " have") for match in matches]
matches = [match.replace("n't", "nt") for match in matches]
matches = [match.replace("'d", " did") for match in matches]
matches = [match.replace("'ll", " will") for match in matches]

matches = matches[1:-1]

json_objects = [ast.literal_eval(match) for match in matches]
df = pd.DataFrame(json_objects)
df.to_csv('database.csv', index=False)

# %%
ds = pd.read_csv('./database.csv')
ds
# Out:
#                author                                               text
# 0         Jane Austen  The person, be it gentleman or lady, who has n...
# 1        Steve Martin   A day without sunshine is like, you know, night.
# 2    Garrison Keillor  Anyone who thinks sitting in church can make y...
# 3          Jim Henson  Beauty is in the eye of the beholder and it ma...
# 4   Charles M. Schulz  All you need is love. But a little chocolate n...
# 5     Suzanne Collins  Remember, we are madly in love, so it is all r...
# 6    Charles Bukowski  Some people never go crazy. What truly horribl...
# 7     Terry Pratchett  The trouble with having an open mind, of cours...
# 8           Dr. Seuss  Think left and think right and think low and t...
# 9       George Carlin  The reason I talk to myself is because I am th...
# 10        W.C. Fields  I am free of all prejudice. I hate everyone eq...
# 11        Jane Austen  A lady is imagination is very rapid; it jumps ...
